# %% [markdown]
# # Упражнения
# В этом упражнении рассматривается прогноз SARIMA, аналогичный тому, который был сделан для набора данных $CO_2$.

# %%
# !pip install pmdarima
# Out:
# Requirement already satisfied: pmdarima in c:\users\e.dvortsova\anaconda3\lib\site-packages (1.8.4)
# Requirement already satisfied: pandas>=0.19 in c:\users\e.dvortsova\anaconda3\lib\site-packages (from pmdarima) (1.2.4)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\e.dvortsova\anaconda3\lib\site-packages (from pmdarima) (52.0.0.post20210125)
# Requirement already satisfied: urllib3 in c:\users\e.dvortsova\anaconda3\lib\site-packages (from pmdarima) (1.26.4)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\e.dvortsova\anaconda3\lib\site-packages (from pmdarima) (0.24.1)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\e.dvortsova\anaconda3\lib\site-packages (from pmdarima) (1.20.1)
# Requirement already satisfied: statsmodels!=0.12.0,>=0.11 in c:\users\e.dvortsova\anaconda3\lib\site-packages (from pmdarima) (0.12.2)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in c:\users\e.dvortsova\anaconda3\lib\site-packages (from pmdarima) (0.29.23)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\e.dvortsova\anaconda3\lib\site-packages (from pmdarima) (1.6.2)
# Requirement already satisfied: joblib>=0.11 in c:\users\e.dvortsova\anaconda3\lib\site-packages (from pmdarima) (1.0.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\e.dvortsova\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\e.dvortsova\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\e.dvortsova\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.19->pmdarima) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\e.dvortsova\anaconda3\lib\site-packages (from scikit-learn>=0.22->pmdarima) (2.1.0)
# Requirement already satisfied: patsy>=0.5 in c:\users\e.dvortsova\anaconda3\lib\site-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.1)

# %%
# 
import pandas as pd
import numpy as np
# %matplotlib inline

# импорт SARIMAX 
from statsmodels.tsa.statespace.sarimax import SARIMAX

from statsmodels.graphics.tsaplots import plot_acf,plot_pacf # для определения (p,q) 
from statsmodels.tsa.seasonal import seasonal_decompose      # для ETS графиков
from pmdarima import auto_arima                              # для поиска ARIMA моделей

# метрики
from sklearn.metrics import mean_squared_error
from statsmodels.tools.eval_measures import rmse

# для игнорирования предупреждений (опционально)
# import warnings
# warnings.filterwarnings("ignore")

# Загрузка датасета
df = pd.read_csv('HospitalityEmployees.csv',index_col='Date',parse_dates=True)
df.index.freq = 'MS'
print(len(df))
print(df.head())
# Out:
# 348
#             Employees
# Date
# 1990-01-01     1064.5
# 1990-02-01     1074.5
# 1990-03-01     1090.0
# 1990-04-01     1097.4
# 1990-05-01     1108.7

# %% [markdown]
# В <tt>df</tt>  348 записей и 1 колонка. Данные представляют собой численность сотрудников в тысячах человек в среднем за месяц с января 1990 года по декабрь 2018 года.

# %% [markdown]
# ### 1. Постройте график временного ряда

# %%
## 

title = 'California Hospitality Industry Employees' 
ylabel = 'Thousands of Persons' 
xlabel = '' 

ax = df['Employees'].plot(figsize=(12,6),title=title) 
ax.autoscale(axis='x',tight=True)
ax.set(xlabel=xlabel, ylabel=ylabel)
# Out:
# [Text(0.5, 0, ''), Text(0, 0.5, 'Thousands of Persons')]

# %%
#

# %% [markdown]
# ### 2. Выполните ETS декомпозицию
# Используя аддитивную модель ('additive').

# %%
r = seasonal_decompose(df['Employees'],model='additive')

# %%
r.plot();

# %%
#

# %% [markdown]
# ### 3. Запустите <tt>pmdarima.auto_arima</tt> чтобы получить набор параметров
# Это может занять некоторое время, так как необходимо оценить множество комбинаций.

# %%
auto_arima(df['Employees'],seasonal=True,m=12).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                  348
# Model:             SARIMAX(1, 1, 2)x(1, 0, [1], 12)   Log Likelihood               -1098.252
# Date:                              Thu, 16 Dec 2021   AIC                           2208.504
# Time:                                      13:15:57   BIC                           2231.600
# Sample:                                           0   HQIC                          2217.700
#                                               - 348
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9246      0.045     20.572      0.000       0.836       1.013
# ma.L1         -0.9441      0.070    -13.541      0.000      -1.081      -0.807
# ma.L2          0.1287      0.060      2.157      0.031       0.012       0.246
# ar.S.L12       0.9972      0.001    706.317      0.000       0.994       1.000
# ma.S.L12      -0.7494      0.043    -17.353      0.000      -0.834      -0.665
# sigma2        29.2905      1.716     17.068      0.000      25.927      32.654
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                67.40
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.86   Skew:                            -0.11
# Prob(H) (two-sided):                  0.40   Kurtosis:                         5.15
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# Ожидаемый результат ARIMA (0,1,0) с сезонностью (2,0,0,12).
# ### 4. Разделите данные на train/test
# Установите один год (12 записей) для тестирования. Есть несколько способов сделать это!

# %%
train = df.iloc[:len(df)-12]
test = df.iloc[len(df)-12:]

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %% [markdown]
# ### 5. Обучите SARIMA(0,1,0)(2,0,0,12) на train

# %%
model = SARIMAX(train['Employees'],order=(1, 1, 2),seasonal_order=(1, 0, 1, 12))
results = model.fit()
results.summary()
# Out:
# C:\Users\e.dvortsova\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\e.dvortsova\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\e.dvortsova\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:997: UserWarning: Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#   warn('Non-stationary starting seasonal autoregressive'
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                            Employees   No. Observations:                  336
# Model:             SARIMAX(1, 1, 2)x(1, 0, [1], 12)   Log Likelihood               -1058.058
# Date:                              Thu, 16 Dec 2021   AIC                           2128.117
# Time:                                      13:17:09   BIC                           2151.001
# Sample:                                  01-01-1990   HQIC                          2137.240
#                                        - 12-01-2017
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9242      0.043     21.309      0.000       0.839       1.009
# ma.L1         -0.9586      0.070    -13.608      0.000      -1.097      -0.821
# ma.L2          0.1498      0.061      2.448      0.014       0.030       0.270
# ar.S.L12       0.9973      0.001    733.473      0.000       0.995       1.000
# ma.S.L12      -0.7522      0.044    -17.167      0.000      -0.838      -0.666
# sigma2        28.7570      1.683     17.084      0.000      25.458      32.056
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                73.31
# Prob(Q):                              0.98   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.91   Skew:                            -0.17
# Prob(H) (two-sided):                  0.63   Kurtosis:                         5.27
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
model = SARIMAX(train['Employees'],order=(1, 1, 2),seasonal_order=(1, 0, 1, 12))
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                            Employees   No. Observations:                  336
# Model:             SARIMAX(1, 1, 2)x(1, 0, [1], 12)   Log Likelihood               -1058.058
# Date:                              Sun, 07 Mar 2021   AIC                           2128.116
# Time:                                      09:40:10   BIC                           2151.001
# Sample:                                  01-01-1990   HQIC                          2137.240
#                                        - 12-01-2017
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9241      0.044     21.235      0.000       0.839       1.009
# ma.L1         -0.9583      0.070    -13.634      0.000      -1.096      -0.821
# ma.L2          0.1497      0.061      2.456      0.014       0.030       0.269
# ar.S.L12       0.9973      0.001    731.206      0.000       0.995       1.000
# ma.S.L12      -0.7519      0.044    -17.166      0.000      -0.838      -0.666
# sigma2        28.7622      1.684     17.079      0.000      25.462      32.063
# ===================================================================================
# Ljung-Box (Q):                       29.90   Jarque-Bera (JB):                73.33
# Prob(Q):                              0.88   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.91   Skew:                            -0.17
# Prob(H) (two-sided):                  0.63   Kurtosis:                         5.27
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
model = SARIMAX(train['Employees'],order=(0, 1, 0),seasonal_order=(2, 0, 0, 12)) #изменяем параметры
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                          Employees   No. Observations:                  336
# Model:             SARIMAX(0, 1, 0)x(2, 0, 0, 12)   Log Likelihood               -1095.407
# Date:                            Thu, 16 Dec 2021   AIC                           2196.814
# Time:                                    13:18:00   BIC                           2208.256
# Sample:                                01-01-1990   HQIC                          2201.375
#                                      - 12-01-2017
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L12       0.5204      0.040     13.051      0.000       0.442       0.599
# ar.S.L24       0.4385      0.041     10.593      0.000       0.357       0.520
# sigma2        37.1907      2.165     17.175      0.000      32.947      41.435
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):                56.66
# Prob(Q):                              0.89   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.06   Skew:                            -0.35
# Prob(H) (two-sided):                  0.74   Kurtosis:                         4.89
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ### 6. Получите прогнозируемые значения

# %%
start=len(train)
end=len(train)+len(test)-1
predictions = results.predict(start=start, end=end, dynamic=False, typ='levels').rename(' Predictions SARIMAX(1, 1, 2)x(1, 0, [1], 12)')

# %%
test['Employees'].plot(legend=True)
predictions.plot(legend=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### 7. Нарисуйте графики прогнозируемых и известных значений

# %%
title = 'California Hospitality Industry Employees' 
ylabel = 'Thousands of Persons' 
xlabel = '' 


ax = test['Employees'].plot(legend=True, figsize=(12,6),title=title) 
predictions.plot(legend=True)
ax.autoscale(axis='x',tight=True)
ax.set(xlabel=xlabel, ylabel=ylabel)
# Out:
# [Text(0.5, 0, ''), Text(0, 0.5, 'Thousands of Persons')]

# %%
#ожидаемый результат

# %%
#сравниваем

# %%
from sklearn.metrics import mean_squared_error
from statsmodels.tools.eval_measures import rmse

mse_error = mean_squared_error(test['Employees'], predictions)
rmse_error = rmse(test['Employees'], predictions)

print(f'SARIMA(0,1,0)(2,0,0,12) MSE Error: {mse_error:11.10}') #квадрат от единиц измерения 11 - кол-во символов (с точкой), 10 - после точки (сколько оставнется, но макс 10) 
print(f'SARIMA(0,1,0)(2,0,0,12) RMSE Error: {rmse_error:11.10}')
# Out:
# SARIMA(0,1,0)(2,0,0,12) MSE Error: 182.8506635
# SARIMA(0,1,0)(2,0,0,12) RMSE Error:  13.5222285

# %% [markdown]
# ### 8. Оцените качество модели с помощью MSE и RMSE

# %%
print(f'SARIMA(0,1,0)(2,0,0,12) MSE Error: {mse_error:11.10}') 
print(f'SARIMA(0,1,0)(2,0,0,12) RMSE Error: {rmse_error:11.10}')
# Out:
# SARIMA(0,1,0)(2,0,0,12) MSE Error: 182.8506635
# SARIMA(0,1,0)(2,0,0,12) RMSE Error:  13.5222285

# %% [markdown]
# ### 9. Натренируйте модель на полном датасете и предскажите на год вперед

# %%
model = SARIMAX(df['Employees'],order=(1, 1, 2),seasonal_order=(1, 0, 1, 12))
results = model.fit()
results.summary()
# Out:
# C:\Users\e.dvortsova\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\e.dvortsova\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\e.dvortsova\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:997: UserWarning: Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#   warn('Non-stationary starting seasonal autoregressive'
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                            Employees   No. Observations:                  348
# Model:             SARIMAX(1, 1, 2)x(1, 0, [1], 12)   Log Likelihood               -1098.252
# Date:                              Thu, 16 Dec 2021   AIC                           2208.504
# Time:                                      13:25:29   BIC                           2231.600
# Sample:                                  01-01-1990   HQIC                          2217.700
#                                        - 12-01-2018
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9246      0.045     20.572      0.000       0.836       1.013
# ma.L1         -0.9441      0.070    -13.541      0.000      -1.081      -0.807
# ma.L2          0.1287      0.060      2.157      0.031       0.012       0.246
# ar.S.L12       0.9972      0.001    706.317      0.000       0.994       1.000
# ma.S.L12      -0.7494      0.043    -17.353      0.000      -0.834      -0.665
# sigma2        29.2905      1.716     17.068      0.000      25.927      32.654
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                67.40
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.86   Skew:                            -0.11
# Prob(H) (two-sided):                  0.40   Kurtosis:                         5.15
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
fcast = results.predict(len(df)-1,len(df)+11,typ='levels').rename('SARIMAX(1, 1, 2)x(1, 0, [1], 12) Forecast')

# %% [markdown]
# ### 10. Постройте график предсказаний и график исходных данных

# %%
fcast.plot()
# df['Employees'][-1]
# Out:
# <AxesSubplot:>

# %%
title = 'California Hospitality Industry Employees' 
ylabel = 'Thousands of Persons' 
xlabel = '' 


ax = df['Employees'].plot(legend=True, figsize=(12,6),title=title) 
fcast.plot(legend=True)
ax.autoscale(axis='x',tight=True)
ax.set(xlabel=xlabel, ylabel=ylabel)
# Out:
# [Text(0.5, 0, ''), Text(0, 0.5, 'Thousands of Persons')]

# %% [markdown]
# ### Бонус: воспользуйтесь библиотекой Prophet для предсказания на 1 год вперед
